# %%
from mlp import *

# %%
mlps = {
    MLP(0.01, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(0.1, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(10.0, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(100.0, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(1000.0, [10], tanh, 0.01, 8*8): [[], [], [], []],
}
iterations = [100]

# %%
run_simulation(mlps, iterations);
# Out:
# 100%|██████████| 100/100 [10:44<00:00,  6.44s/it, 9.01%, 32.23%, 61.28%, 83.65%, 90.8%, 91.2%]
# learning rate: 0.01
# learning rate: 0.1
# learning rate: 1.0
# learning rate: 10.0
# learning rate: 100.0
# learning rate: 1000.0

# %% [markdown]
# Im większy learning rate tym szybciej model się uczy, mówimy tu zarówno o początkowym dopasowaniu (już po jednej iteracji można widzieć znaczną różnicę), jak i o szybkości dopasowywania się modelu. Przy zbyt dużej wartości kroku możemy się spodziewać większej nieregularności w przyroście ze względu na "przeskakiwanie" celu - w nieznacznym stopniu możemy to zaopserwować na powyższym wykresie.
