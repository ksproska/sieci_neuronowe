# %%
from mlp import *

# %%
mlps = {
    MLP(1.0, [10], tanh, 0.01, 1): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.01, 8): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.01, 8*8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.01, 8*8*8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.01, 60000): [[], [], [], []],
}
iterations = [100]

# %%
run_simulation(mlps, iterations)
# Out:
# 100%|██████████| 100/100 [19:50<00:00, 11.91s/it, 0/1]
