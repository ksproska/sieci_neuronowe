# %%
from mlp import *

# %%
mlp = MLP(100.0, [100], tanh, 0.01, 64)
mlps = {mlp: [[], [], [], []]}
iterations = [30]

# %%
run_simulation(mlps, iterations, True, 0.009);
# Out:
#  27%|██▋       | 8/30 [00:15<00:42,  1.95s/it, 89.97%]No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#  27%|██▋       | 8/30 [00:17<00:47,  2.16s/it, 89.97%]

# %%
mlp.update_params(learning_rate= 10.0, batch_size= 8)
run_simulation(mlps, iterations, True, 0.01);
# Out:
#  23%|██▎       | 7/30 [00:37<02:04,  5.40s/it, 90.56%]No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#  23%|██▎       | 7/30 [00:43<02:22,  6.22s/it, 90.56%]
