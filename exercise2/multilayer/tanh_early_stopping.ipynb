# %%
from mlp import *

# %%
mlp = MLP(100.0, [100], tanh, 0.01, 64)
mlps = {mlp: [[], [], [], []]}
iterations = [30]

# %%
run_simulation(mlps, iterations, True, 0.009);
# Out:
#  10%|█         | 3/30 [00:06<00:54,  2.04s/it, 86.68%]No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#  10%|█         | 3/30 [00:08<01:17,  2.86s/it, 86.68%]

# %%
mlp.update_params(learning_rate= 10.0, batch_size= 8)
run_simulation(mlps, iterations, True, 0.011);
# Out:
# 100%|██████████| 30/30 [02:55<00:00,  5.85s/it, 89.87%]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
