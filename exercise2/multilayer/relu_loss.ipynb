# %%
from mlp import *

# %%
mlps = {
    MLP(1.0, [100], relu, 0.01, 64): [[], [], [], []],
}
iterations = [10] * 10

# %%
run_simulation(mlps, iterations, True);
# Out:
# 100%|██████████| 10/10 [01:17<00:00,  7.80s/it, 79.72%]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#  10%|█         | 1/10 [00:07<01:10,  7.83s/it, 80.32%]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 run_simulation(mlps, iterations, True)
#
# File ~/PycharmProjects/sieci_neuronowe/exercise2/multilayer/mlp.py:164, in run_simulation(mlps, iterations, show_train)
#     162 for _ in smart_iterator:
#     163     for mlp in mlps.keys():
# --> 164         mlp.train_one_epoch()
#     165         loss_train, prediction_train = mlp.get_predictions(mlp.train_X, mlp.d_train)
#     166         loss_test, prediction_test = mlp.get_predictions(mlp.test_X, mlp.d_test)
#
# File ~/PycharmProjects/sieci_neuronowe/exercise2/multilayer/mlp.py:84, in MLP.train_one_epoch(self)
#      82 b = self.all_bs[j]
#      83 z = w @ a_all[j] + b
# ---> 84 z_all.append(z)
#      85 a = f(z)
#      86 a_all.append(a)
#
# KeyboardInterrupt:

# %% [markdown]
# Linia przerywana oznacza wartości precyzji i błędu dla zbioru treningowego, a linia ciągła dla zbioru testowego.
# Jak można zauważyć przy ok 2 iteracjach wartości w zarówno precyzji jak i błędu zaczynają się różnić dla obu zbiorów.
# Wynika to z faktu, że model dopoasowuje się do zadanego problemu (zbioru treningowego) i polepsza swoją skuteczność, ale oznacza  to utratę uogólnienia - uczy się "na pamięć". Dla zbioru treninowego poprawanie jest znaczna, przez co sugerowane byłoby w tym miejscu zatrzymać uczenie całkowicie, albo wznowić je z innymi parametrami.
