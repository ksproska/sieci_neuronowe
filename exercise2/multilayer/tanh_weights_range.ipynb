# %%
from mlp import *
# Out:
# 2022-11-06 11:51:49.905814: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 11:51:50.111451: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-06 11:51:50.111504: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-06 11:51:50.165654: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
mlps = {
    MLP(1.0, [10], tanh, 0.01, 8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 0.1, 8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 1.0, 8*8): [[], [], [], []],
    MLP(1.0, [10], tanh, 10.0, 8*8): [[], [], [], []],
}
iterations = [100]

# %%
run_simulation(mlps, iterations);
# Out:
# 100%|██████████| 100/100 [17:50<00:00, 10.71s/it, 65.77%, 63.56%, 57.93%, 55.79%]
# weights ranges: -0.01:0.01
# weights ranges: -0.1:0.1
# weights ranges: -1.0:1.0
# weights ranges: -10.0:10.0
