# %%
from mlp import *
# Out:
# 2022-11-06 12:57:34.556861: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 12:57:34.752338: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-06 12:57:34.752384: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-06 12:57:34.808784: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
mlps = {
    MLP(0.01, [10], relu, 0.01, 8*8): [[], [], [], []],
    MLP(0.1, [10], relu, 0.01, 8*8): [[], [], [], []],
    MLP(1.0, [10], relu, 0.01, 8*8): [[], [], [], []],
    MLP(10.0, [10], relu, 0.01, 8*8): [[], [], [], []],
    MLP(100.0, [10], relu, 0.01, 8*8): [[], [], [], []],
    MLP(1000.0, [10], relu, 0.01, 8*8): [[], [], [], []],
}
iterations = [100]

# %%
run_simulation(mlps, iterations);
# Out:
# 100%|██████████| 100/100 [42:13<00:00, 25.33s/it, 15.44%, 32.3%, 43.64%, 81.65%, 90.78%, 27.54%]
# learning rate: 0.01
# learning rate: 0.1
# learning rate: 1.0
# learning rate: 10.0
# learning rate: 100.0
# learning rate: 1000.0

# %% [markdown]
# Im większy learning rate tym szybciej model się uczy, mówimy tu zarówno o początkowym dopasowaniu (już po jednej iteracji można widzieć znaczną różnicę), jak i o szybkości dopasowywania się modelu.
